# %%
import numpy as np
import pandas as pd
import librosa
import IPython.display
import os
import sys
import audioread
from python_speech_features import mfcc
from python_speech_features import delta
from python_speech_features import logfbank
import scipy.io.wavfile as wav
import pickle

# %%
def format_seconds(s):
    mins = int(s / 60)
    secs = s - 60*mins
    return "%d:%0.2f" % (mins, secs)

# %%
t_root = "/data/corpora/switchboard-1/swb_ms98_transcriptions/"
a_root = "/data/corpora/switchboard-1/97S62/"

# %%
def get_train_val_test_folders(t_root):
    t_folders = [t_root + f for f in os.listdir(t_root) if os.path.isdir(t_root + f)]
    t_folders.sort()
    train_folders = t_folders[0:20]
    val_folders = t_folders[20:25]
    test_folders = t_folders[25:30]
    train_folders.sort(); val_folders.sort(); test_folders.sort()
    return (train_folders, val_folders, test_folders)

def get_transcriptions_files(folder):
    files = []
    subfolders = [folder + "/" + f for f in os.listdir(folder)]
    for f in subfolders:
        fs = [f + "/" + fname for fname in os.listdir(f) if 'a-word.text' in fname and 'A' in fname]
        files += fs
    files.sort()
    return files

def get_all_transcriptions_files(folder_list):
    files = []
    for folder in folder_list:
        files += get_transcriptions_files(folder)
    files.sort()
    return files

def get_transcription_files_with_laughter_in_corpus(folder_list):
    files = []
    transcription_files = get_all_transcriptions_files(folder_list)
    for f in transcription_files:
        if count_laughter_instances_in_transcription_file(f) > 0:
            files.append(f)
    return files

def count_transcription_files_with_laughter_in_corpus(folder_list):
    return len(get_transcription_files_with_laughter_in_corpus(folder_list))

# %%
def get_sph_files(folder):
    return [folder + "/" + f for f in os.listdir(folder) if ".sph" in f]

def get_all_audio_files(a_root):
    files = []
    a_folders = [a_root + f + "/data" for f in os.listdir(a_root) if os.path.isdir(a_root + f)]
    a_folders.sort()
    for folder in a_folders:
        files += get_sph_files(folder)
    files.sort()
    return files

# %%
def get_text_from_file(f):
    return (open(f).read().split("\n"))[0:-1]

def get_laughter_rows_from_file(f):
    return [l for l in get_text_from_file(f) if 'laughter' in l]
    #return [l for l in get_text_from_file(f) if 'laughter' in l] # allows laughter with words together

def get_audio_file_from_id(d):
    files = [f for f in all_audio_files if d in f]
    if len(files) == 1:
        return files[0]
    elif len(files) > 1:
        print "More than 1 audio file matched id %d" % (int(d))
        return None
    else:
        print "No audio file matched id %d" % (int(d))
        return None
        
def get_id_from_row(row):
    return row[2:6]

def get_id_from_file(f):
    return get_id_from_row(get_text_from_file(f)[0])

def get_audio_file_from_row(row):
    return get_audio_file_from_id(get_id_from_row(row))

def get_audio_file_from_transcription_text(t):
    return get_audio_file_from_id(get_id_from_row(t[0]))

def get_audio_file_from_transcription_file(f):
    t = open(f).read().split('\n')
    return get_audio_file_from_id(get_id_from_row(t[0]))

def get_audio_file_length(path):
    f = audioread.audio_open(path)
    l = f.duration
    f.close()
    return l

# %%
def count_laughter_instances_in_transcription_file(f):
    rows = get_laughter_rows_from_file(f)
    return len(rows)

def count_laughter_instances_in_corpus(folder_list):
    transcription_files = get_all_transcriptions_files(folder_list)
    count = 0
    for f in transcription_files:
        count += count_laughter_instances_in_transcription_file(f)
    return count

# %%
def get_audio_files_from_transcription_files(transcription_files):
    files = []
    for f in transcription_files:
        files.append(get_audio_file_from_transcription_file(f))
    files = list(set(files))
    files.sort()
    if None in files: files.remove(None)
    return files

# %%
all_audio_files = get_all_audio_files(a_root)
train_folders, val_folders, test_folders = get_train_val_test_folders(t_root)

# %%
print "Laughter instances in training data: %d" % (count_laughter_instances_in_corpus(train_folders))
print "Laughter instances in validation data: %d" % (count_laughter_instances_in_corpus(val_folders))
print "Laughter instances in test data: %d" % ( count_laughter_instances_in_corpus(test_folders))
print
print "Files containing laughter in training data: %d" % (count_transcription_files_with_laughter_in_corpus(train_folders))
print "Files containing laughter in validation data: %d" % (count_transcription_files_with_laughter_in_corpus(val_folders))
print "Files containing laughter in test data: %d" % (count_transcription_files_with_laughter_in_corpus(test_folders))
# Out:
# Laughter instances in training data: 14760
# Laughter instances in validation data: 2056
# Laughter instances in test data: 1004
#
# Files containing laughter in training data: 1706
# Files containing laughter in validation data: 346
# Files containing laughter in test data: 155

# %%
train_audio_files = get_audio_files_from_transcription_files(get_all_transcriptions_files(train_folders))
val_audio_files = get_audio_files_from_transcription_files(get_all_transcriptions_files(val_folders))
test_audio_files = get_audio_files_from_transcription_files(get_all_transcriptions_files(test_folders))

print len(all_audio_files)
print len(train_audio_files) + len(test_audio_files) + len(val_audio_files)
# Out:
# No audio file matched id 2289
# No audio file matched id 4361
# No audio file matched id 4379
# 2435
# 2435

# %%
train_transcription_files = get_transcription_files_with_laughter_in_corpus(train_folders)
val_transcription_files = get_transcription_files_with_laughter_in_corpus(val_folders)
test_transcription_files = get_transcription_files_with_laughter_in_corpus(test_folders)

# %%
train_audio_files = get_audio_files_from_transcription_files(train_transcription_files)
val_audio_files = get_audio_files_from_transcription_files(val_transcription_files)
test_audio_files = get_audio_files_from_transcription_files(test_transcription_files)
print len(train_audio_files)
print len(val_audio_files) 
print len(test_audio_files)
# Out:
# No audio file matched id 2289
# No audio file matched id 4361
# No audio file matched id 4379
# 1705
# 344
# 155

# %%
def extract_times_from_row(row):
    return (float(row.split(' ')[1]), float(row.split(' ')[2]))

def get_laughter_regions_from_file(t_file):
    rows = get_laughter_rows_from_file(t_file)
    times = []
    for row in rows:
        start, end = extract_times_from_row(row)
        if end - start > 0.05:
            times.append((start,end))
    return times

def get_length_from_regions_list(times):
    return sum([end - start for start, end in times])
    
def get_random_speech_region_from_file(t_file, region_length):
    audio_length = get_audio_file_length(get_audio_file_from_transcription_file(t_file))
    contains_laughter = True
    tries = 0
    while(contains_laughter):
        tries += 1
        if tries > 10:
            print "audio length %f" % (audio_length)
            print "region legnth %f" % (region_length)
            return None
        start = np.random.uniform(1.0, audio_length - region_length - 1.0)
        end = start + region_length
        if no_laughter_present(t_file,start,end):
            contains_laughter = False
    return (start, end)

# Check if laughter is present in a region of an audio file by looking at the transcription file
def no_laughter_present(t_file,start,end):
    all_rows = get_text_from_file(t_file)
    for row in all_rows:
        region_start, region_end = extract_times_from_row(row)
        if times_overlap(float(region_start), float(region_end), float(start), float(end)):
            if 'laughter' in row.split(' ')[-1]:
                return False
    return True
        
def times_overlap(start1, end1, start2, end2):
    if end1 < start2 or end2 < start1:
        return False
    else:
        return True

# %%
# pad with 0.5 seconds on each side of the desired region
def clip_audio_region(y,sr,start,end,pad_amount=0.5):
    start_sample = int((start-pad_amount)*sr)
    end_sample = int((end+pad_amount)*sr)
    return y[start_sample:end_sample]

def write_clip_to_disk(path,y,sr):
    librosa.output.write_wav(path,y,sr)
    
def compute_mfcc_features(y,sr):
    return mfcc(y,samplerate=sr,winlen=0.025,winstep=0.01)

def compute_delta_features(mfcc_feat):
    return delta(mfcc_feat, 2)

def compute_labels_per_frame(n_frames,sr,winstep=0.01,pad_amount=0.5):
    #print "n_frames: %d" % (n_frames)
    samples_per_frame = sr*winstep #80 with defaults
    #with 0.5 seconds of padding, there should be 4000 samples of padding, so 50 frames of non-laughter 
    n_padding_frames = int(sr * pad_amount / samples_per_frame)
    padding_frames = list(np.zeros(n_padding_frames))
    laughter_frames = list(np.ones(n_frames - 2*n_padding_frames))
    labels = padding_frames + laughter_frames + padding_frames
    return labels

# %%
def compute_features_and_labels(y,sr,region,label_type,source_file_id,file_index):
    clip = clip_audio_region(y,sr,start=region[0],end=region[1])
    mfcc_features = compute_mfcc_features(clip,sr)
    delta_features = compute_delta_features(mfcc_features)
    n_frames = len(mfcc_features)
    if label_type == 'laughter':
        labels = compute_labels_per_frame(n_frames,sr)
    else:
        labels = np.zeros(n_frames)
    return {'mfcc': mfcc_features,
            'delta': delta_features,
            'labels': labels,
            'clip_type': label_type,
            'source_file_id': source_file_id,
            'file_index': file_index}

# %%
def compute_and_store_features_and_labels(t_file, output_dir):
    a_file = get_audio_file_from_transcription_file(t_file)
    y,sr = librosa.load(a_file,sr=8000)
    source_file_id = get_id_from_file(t_file)
    laughter_regions = get_laughter_regions_from_file(t_file)
    
    laughter_features_list = [compute_features_and_labels(y,sr,region,label_type='laughter',source_file_id=source_file_id,file_index=index) for index, region in enumerate(laughter_regions)]
    speech_regions = [get_random_speech_region_from_file(t_file, get_length_from_regions_list(laughter_regions)) for i in xrange(3)]
    speech_features_list = [compute_features_and_labels(y,sr,region,label_type='speech',source_file_id=source_file_id,file_index=index) for index, region in enumerate(speech_regions)]
    
    laughter_output_file = output_dir + "laughter_" + source_file_id + ".pkl"
    speech_output_file = output_dir + "speech_" + source_file_id + ".pkl"
    
    with open(laughter_output_file, "wb") as f:
        pickle.dump(laughter_features_list, f)

    with open(speech_output_file, "wb") as f:
        pickle.dump(speech_features_list, f)

# %%
TRAIN_OUTPUT_DIR = "/data/jrgillick/laughter/stored_features3/train_set/"
VALIDATION_OUTPUT_DIR = "/data/jrgillick/laughter/stored_features3/val_set/"
TEST_OUTPUT_DIR = "/data/jrgillick/laughter/stored_features3/test_set/"

# %%
def compute_all_features(transcription_file_list, output_dir):
    for index, t_file in enumerate(transcription_file_list):
        print "Processing %d out of %d transcription files." % (index+1, len(transcription_file_list))
        try:
            compute_and_store_features_and_labels(t_file, output_dir)
        except:
            print "File %d Failed" % (index + 1)

# %%
compute_all_features(train_transcription_files, TRAIN_OUTPUT_DIR)
# Out:
# Processing 1 out of 1706 transcription files.
# Processing 2 out of 1706 transcription files.
# Processing 3 out of 1706 transcription files.
# Processing 4 out of 1706 transcription files.
# Processing 5 out of 1706 transcription files.
# Processing 6 out of 1706 transcription files.
# Processing 7 out of 1706 transcription files.
# Processing 8 out of 1706 transcription files.
# Processing 9 out of 1706 transcription files.
# Processing 10 out of 1706 transcription files.
# audio length 230.000000
# region legnth 32.391000
# audio length 230.000000
# region legnth 32.391000
# audio length 230.000000
# region legnth 32.391000
# ID 9 Failed
# Processing 11 out of 1706 transcription files.
# Processing 12 out of 1706 transcription files.
# Processing 13 out of 1706 transcription files.
# Processing 14 out of 1706 transcription files.
# Processing 15 out of 1706 transcription files.
# Processing 16 out of 1706 transcription files.
# Processing 17 out of 1706 transcription files.
# Processing 18 out of 1706 transcription files.
# Processing 19 out of 1706 transcription files.
# Processing 20 out of 1706 transcription files.
# Processing 21 out of 1706 transcription files.
# Processing 22 out of 1706 transcription files.
# Processing 23 out of 1706 transcription files.
# Processing 24 out of 1706 transcription files.
# Processing 25 out of 1706 transcription files.
# Processing 26 out of 1706 transcription files.
# Processing 27 out of 1706 transcription files.
# Processing 28 out of 1706 transcription files.
# Processing 29 out of 1706 transcription files.
# Processing 30 out of 1706 transcription files.
# Processing 31 out of 1706 transcription files.
# Processing 32 out of 1706 transcription files.
# Processing 33 out of 1706 transcription files.
# Processing 34 out of 1706 transcription files.
# Processing 35 out of 1706 transcription files.
# Processing 36 out of 1706 transcription files.
# Processing 37 out of 1706 transcription files.
# Processing 38 out of 1706 transcription files.
# Processing 39 out of 1706 transcription files.
# Processing 40 out of 1706 transcription files.
# Processing 41 out of 1706 transcription files.
# Processing 42 out of 1706 transcription files.
# Processing 43 out of 1706 transcription files.
# Processing 44 out of 1706 transcription files.
# Processing 45 out of 1706 transcription files.
# Processing 46 out of 1706 transcription files.
# Processing 47 out of 1706 transcription files.
# Processing 48 out of 1706 transcription files.
# Processing 49 out of 1706 transcription files.
# Processing 50 out of 1706 transcription files.
# Processing 51 out of 1706 transcription files.
# Processing 52 out of 1706 transcription files.
# Processing 53 out of 1706 transcription files.
# Processing 54 out of 1706 transcription files.
# Processing 55 out of 1706 transcription files.
# Processing 56 out of 1706 transcription files.
# Processing 57 out of 1706 transcription files.
# Processing 58 out of 1706 transcription files.
# Processing 59 out of 1706 transcription files.
# Processing 60 out of 1706 transcription files.
# Processing 61 out of 1706 transcription files.
# Processing 62 out of 1706 transcription files.
# audio length 531.500000
# region legnth 31.731250
# audio length 531.500000
# region legnth 31.731250
# ID 61 Failed
# Processing 63 out of 1706 transcription files.
# Processing 64 out of 1706 transcription files.
# Processing 65 out of 1706 transcription files.
# Processing 66 out of 1706 transcription files.
# Processing 67 out of 1706 transcription files.
# Processing 68 out of 1706 transcription files.
# Processing 69 out of 1706 transcription files.
# Processing 70 out of 1706 transcription files.
# Processing 71 out of 1706 transcription files.
# Processing 72 out of 1706 transcription files.
# Processing 73 out of 1706 transcription files.
# Processing 74 out of 1706 transcription files.
# Processing 75 out of 1706 transcription files.
# Processing 76 out of 1706 transcription files.
# Processing 77 out of 1706 transcription files.
# Processing 78 out of 1706 transcription files.
# Processing 79 out of 1706 transcription files.
# Processing 80 out of 1706 transcription files.
# Processing 81 out of 1706 transcription files.
# Processing 82 out of 1706 transcription files.
# Processing 83 out of 1706 transcription files.
# Processing 84 out of 1706 transcription files.
# Processing 85 out of 1706 transcription files.
# Processing 86 out of 1706 transcription files.
# Processing 87 out of 1706 transcription files.
# Processing 88 out of 1706 transcription files.
# Processing 89 out of 1706 transcription files.
# Processing 90 out of 1706 transcription files.
# Processing 91 out of 1706 transcription files.
# Processing 92 out of 1706 transcription files.
# Processing 93 out of 1706 transcription files.
# Processing 94 out of 1706 transcription files.
# Processing 95 out of 1706 transcription files.
# Processing 96 out of 1706 transcription files.
# Processing 97 out of 1706 transcription files.
# Processing 98 out of 1706 transcription files.
# Processing 99 out of 1706 transcription files.
# Processing 100 out of 1706 transcription files.
# Processing 101 out of 1706 transcription files.
# Processing 102 out of 1706 transcription files.
# Processing 103 out of 1706 transcription files.
# Processing 104 out of 1706 transcription files.
# Processing 105 out of 1706 transcription files.
# Processing 106 out of 1706 transcription files.
# Processing 107 out of 1706 transcription files.
# Processing 108 out of 1706 transcription files.
# Processing 109 out of 1706 transcription files.
# Processing 110 out of 1706 transcription files.
# Processing 111 out of 1706 transcription files.
# Processing 112 out of 1706 transcription files.
# Processing 113 out of 1706 transcription files.
# Processing 114 out of 1706 transcription files.
# Processing 115 out of 1706 transcription files.
# Processing 116 out of 1706 transcription files.
# Processing 117 out of 1706 transcription files.
# Processing 118 out of 1706 transcription files.
# Processing 119 out of 1706 transcription files.
# Processing 120 out of 1706 transcription files.
# Processing 121 out of 1706 transcription files.
# Processing 122 out of 1706 transcription files.
# Processing 123 out of 1706 transcription files.
# Processing 124 out of 1706 transcription files.
# Processing 125 out of 1706 transcription files.
# Processing 126 out of 1706 transcription files.
# Processing 127 out of 1706 transcription files.
# Processing 128 out of 1706 transcription files.
# Processing 129 out of 1706 transcription files.
# Processing 130 out of 1706 transcription files.
# Processing 131 out of 1706 transcription files.
# ID 130 Failed
# Processing 132 out of 1706 transcription files.
# Processing 133 out of 1706 transcription files.
# Processing 134 out of 1706 transcription files.
# Processing 135 out of 1706 transcription files.
# Processing 136 out of 1706 transcription files.
# Processing 137 out of 1706 transcription files.
# Processing 138 out of 1706 transcription files.
# Processing 139 out of 1706 transcription files.
# Processing 140 out of 1706 transcription files.
# Processing 141 out of 1706 transcription files.
# Processing 142 out of 1706 transcription files.
# Processing 143 out of 1706 transcription files.
# Processing 144 out of 1706 transcription files.
# Processing 145 out of 1706 transcription files.
# Processing 146 out of 1706 transcription files.
# Processing 147 out of 1706 transcription files.
# Processing 148 out of 1706 transcription files.
# Processing 149 out of 1706 transcription files.
# Processing 150 out of 1706 transcription files.
# Processing 151 out of 1706 transcription files.
# Processing 152 out of 1706 transcription files.
# Processing 153 out of 1706 transcription files.
# ID 152 Failed
# Processing 154 out of 1706 transcription files.
# Processing 155 out of 1706 transcription files.
# Processing 156 out of 1706 transcription files.
# Processing 157 out of 1706 transcription files.
# Processing 158 out of 1706 transcription files.
# Processing 159 out of 1706 transcription files.
# Processing 160 out of 1706 transcription files.
# Processing 161 out of 1706 transcription files.
# Processing 162 out of 1706 transcription files.
# Processing 163 out of 1706 transcription files.
# Processing 164 out of 1706 transcription files.
# Processing 165 out of 1706 transcription files.
# Processing 166 out of 1706 transcription files.
# Processing 167 out of 1706 transcription files.
# Processing 168 out of 1706 transcription files.
# Processing 169 out of 1706 transcription files.
# Processing 170 out of 1706 transcription files.
# Processing 171 out of 1706 transcription files.
# Processing 172 out of 1706 transcription files.
# Processing 173 out of 1706 transcription files.
# Processing 174 out of 1706 transcription files.
# Processing 175 out of 1706 transcription files.
# Processing 176 out of 1706 transcription files.
# Processing 177 out of 1706 transcription files.
# Processing 178 out of 1706 transcription files.
# Processing 179 out of 1706 transcription files.
# Processing 180 out of 1706 transcription files.
# Processing 181 out of 1706 transcription files.
# Processing 182 out of 1706 transcription files.
# Processing 183 out of 1706 transcription files.
# Processing 184 out of 1706 transcription files.
# Processing 185 out of 1706 transcription files.
# Processing 186 out of 1706 transcription files.
# Processing 187 out of 1706 transcription files.
# Processing 188 out of 1706 transcription files.
# Processing 189 out of 1706 transcription files.
# Processing 190 out of 1706 transcription files.
# Processing 191 out of 1706 transcription files.
# Processing 192 out of 1706 transcription files.
# Processing 193 out of 1706 transcription files.
# Processing 194 out of 1706 transcription files.
# Processing 195 out of 1706 transcription files.
# Processing 196 out of 1706 transcription files.
# Processing 197 out of 1706 transcription files.
# Processing 198 out of 1706 transcription files.
# audio length 599.000000
# region legnth 38.180500
# audio length 599.000000
# region legnth 38.180500
# ID 197 Failed
# Processing 199 out of 1706 transcription files.
# No audio file matched id 2289
# ID 198 Failed
# Processing 200 out of 1706 transcription files.
# Processing 201 out of 1706 transcription files.
# Processing 202 out of 1706 transcription files.
# Processing 203 out of 1706 transcription files.
# Processing 204 out of 1706 transcription files.
# Processing 205 out of 1706 transcription files.
# Processing 206 out of 1706 transcription files.
# Processing 207 out of 1706 transcription files.
# Processing 208 out of 1706 transcription files.
# Processing 209 out of 1706 transcription files.
# Processing 210 out of 1706 transcription files.
# Processing 211 out of 1706 transcription files.
# Processing 212 out of 1706 transcription files.
# Processing 213 out of 1706 transcription files.
# Processing 214 out of 1706 transcription files.
# Processing 215 out of 1706 transcription files.
# Processing 216 out of 1706 transcription files.
# Processing 217 out of 1706 transcription files.
# Processing 218 out of 1706 transcription files.
# Processing 219 out of 1706 transcription files.
# Processing 220 out of 1706 transcription files.
# Processing 221 out of 1706 transcription files.
# Processing 222 out of 1706 transcription files.
# Processing 223 out of 1706 transcription files.
# Processing 224 out of 1706 transcription files.
# Processing 225 out of 1706 transcription files.
# Processing 226 out of 1706 transcription files.
# Processing 227 out of 1706 transcription files.
# Processing 228 out of 1706 transcription files.
# Processing 229 out of 1706 transcription files.
# Processing 230 out of 1706 transcription files.
# Processing 231 out of 1706 transcription files.
# Processing 232 out of 1706 transcription files.
# Processing 233 out of 1706 transcription files.
# Processing 234 out of 1706 transcription files.
# Processing 235 out of 1706 transcription files.
# Processing 236 out of 1706 transcription files.
# Processing 237 out of 1706 transcription files.
# Processing 238 out of 1706 transcription files.
# Processing 239 out of 1706 transcription files.
# Processing 240 out of 1706 transcription files.
# Processing 241 out of 1706 transcription files.
# Processing 242 out of 1706 transcription files.
# Processing 243 out of 1706 transcription files.
# Processing 244 out of 1706 transcription files.
# Processing 245 out of 1706 transcription files.
# Processing 246 out of 1706 transcription files.
# Processing 247 out of 1706 transcription files.
# Processing 248 out of 1706 transcription files.
# Processing 249 out of 1706 transcription files.
# Processing 250 out of 1706 transcription files.
# Processing 251 out of 1706 transcription files.
# Processing 252 out of 1706 transcription files.
# Processing 253 out of 1706 transcription files.
# Processing 254 out of 1706 transcription files.
# Processing 255 out of 1706 transcription files.
# Processing 256 out of 1706 transcription files.
# Processing 257 out of 1706 transcription files.
# Processing 258 out of 1706 transcription files.
# Processing 259 out of 1706 transcription files.
# Processing 260 out of 1706 transcription files.
# Processing 261 out of 1706 transcription files.
# Processing 262 out of 1706 transcription files.
# Processing 263 out of 1706 transcription files.
# Processing 264 out of 1706 transcription files.
# Processing 265 out of 1706 transcription files.
# Processing 266 out of 1706 transcription files.
# Processing 267 out of 1706 transcription files.
# Processing 268 out of 1706 transcription files.
# Processing 269 out of 1706 transcription files.
# Processing 270 out of 1706 transcription files.
# Processing 271 out of 1706 transcription files.
# Processing 272 out of 1706 transcription files.
# Processing 273 out of 1706 transcription files.
# Processing 274 out of 1706 transcription files.
# Processing 275 out of 1706 transcription files.
# Processing 276 out of 1706 transcription files.
# Processing 277 out of 1706 transcription files.
# Processing 278 out of 1706 transcription files.
# Processing 279 out of 1706 transcription files.
# Processing 280 out of 1706 transcription files.
# Processing 281 out of 1706 transcription files.
# Processing 282 out of 1706 transcription files.
# Processing 283 out of 1706 transcription files.
# Processing 284 out of 1706 transcription files.
# Processing 285 out of 1706 transcription files.
# Processing 286 out of 1706 transcription files.
# Processing 287 out of 1706 transcription files.
# Processing 288 out of 1706 transcription files.
# Processing 289 out of 1706 transcription files.
# Processing 290 out of 1706 transcription files.
# Processing 291 out of 1706 transcription files.
# Processing 292 out of 1706 transcription files.
# Processing 293 out of 1706 transcription files.
# Processing 294 out of 1706 transcription files.
# ID 293 Failed
# Processing 295 out of 1706 transcription files.
# Processing 296 out of 1706 transcription files.
# Processing 297 out of 1706 transcription files.
# Processing 298 out of 1706 transcription files.
# Processing 299 out of 1706 transcription files.
# Processing 300 out of 1706 transcription files.
# Processing 301 out of 1706 transcription files.
# Processing 302 out of 1706 transcription files.
# Processing 303 out of 1706 transcription files.
# Processing 304 out of 1706 transcription files.
# Processing 305 out of 1706 transcription files.
# Processing 306 out of 1706 transcription files.
# Processing 307 out of 1706 transcription files.
# Processing 308 out of 1706 transcription files.
# Processing 309 out of 1706 transcription files.
# Processing 310 out of 1706 transcription files.
# Processing 311 out of 1706 transcription files.
# Processing 312 out of 1706 transcription files.
# Processing 313 out of 1706 transcription files.
# Processing 314 out of 1706 transcription files.
# Processing 315 out of 1706 transcription files.
# Processing 316 out of 1706 transcription files.
# Processing 317 out of 1706 transcription files.
# Processing 318 out of 1706 transcription files.
# Processing 319 out of 1706 transcription files.
# Processing 320 out of 1706 transcription files.
# Processing 321 out of 1706 transcription files.
# Processing 322 out of 1706 transcription files.
# Processing 323 out of 1706 transcription files.
# Processing 324 out of 1706 transcription files.
# Processing 325 out of 1706 transcription files.
# Processing 326 out of 1706 transcription files.
# Processing 327 out of 1706 transcription files.
# Processing 328 out of 1706 transcription files.
# Processing 329 out of 1706 transcription files.
# Processing 330 out of 1706 transcription files.
# Processing 331 out of 1706 transcription files.
# Processing 332 out of 1706 transcription files.
# Processing 333 out of 1706 transcription files.
# Processing 334 out of 1706 transcription files.
# Processing 335 out of 1706 transcription files.
# Processing 336 out of 1706 transcription files.
# Processing 337 out of 1706 transcription files.
# Processing 338 out of 1706 transcription files.
# Processing 339 out of 1706 transcription files.
# Processing 340 out of 1706 transcription files.
# Processing 341 out of 1706 transcription files.
# Processing 342 out of 1706 transcription files.
# Processing 343 out of 1706 transcription files.
# Processing 344 out of 1706 transcription files.
# Processing 345 out of 1706 transcription files.
# Processing 346 out of 1706 transcription files.
# Processing 347 out of 1706 transcription files.
# Processing 348 out of 1706 transcription files.
# Processing 349 out of 1706 transcription files.
# Processing 350 out of 1706 transcription files.
# Processing 351 out of 1706 transcription files.
# Processing 352 out of 1706 transcription files.
# Processing 353 out of 1706 transcription files.
# Processing 354 out of 1706 transcription files.
# Processing 355 out of 1706 transcription files.
# Processing 356 out of 1706 transcription files.
# Processing 357 out of 1706 transcription files.
# Processing 358 out of 1706 transcription files.
# Processing 359 out of 1706 transcription files.
# Processing 360 out of 1706 transcription files.
# Processing 361 out of 1706 transcription files.
# Processing 362 out of 1706 transcription files.
# Processing 363 out of 1706 transcription files.
# Processing 364 out of 1706 transcription files.
# Processing 365 out of 1706 transcription files.
# Processing 366 out of 1706 transcription files.
# Processing 367 out of 1706 transcription files.
# Processing 368 out of 1706 transcription files.
# Processing 369 out of 1706 transcription files.
# Processing 370 out of 1706 transcription files.
# Processing 371 out of 1706 transcription files.
# Processing 372 out of 1706 transcription files.
# Processing 373 out of 1706 transcription files.
# Processing 374 out of 1706 transcription files.
# Processing 375 out of 1706 transcription files.
# Processing 376 out of 1706 transcription files.
# Processing 377 out of 1706 transcription files.
# Processing 378 out of 1706 transcription files.
# Processing 379 out of 1706 transcription files.
# Processing 380 out of 1706 transcription files.
# Processing 381 out of 1706 transcription files.
# Processing 382 out of 1706 transcription files.
# Processing 383 out of 1706 transcription files.
# Processing 384 out of 1706 transcription files.
# Processing 385 out of 1706 transcription files.
# Processing 386 out of 1706 transcription files.
# audio length 599.100000
# region legnth 44.467625
# audio length 599.100000
# region legnth 44.467625
# ID 385 Failed
# Processing 387 out of 1706 transcription files.
# Processing 388 out of 1706 transcription files.
# Processing 389 out of 1706 transcription files.
# Processing 390 out of 1706 transcription files.
# Processing 391 out of 1706 transcription files.
# Processing 392 out of 1706 transcription files.
# Processing 393 out of 1706 transcription files.
# Processing 394 out of 1706 transcription files.
# Processing 395 out of 1706 transcription files.
# Processing 396 out of 1706 transcription files.
# Processing 397 out of 1706 transcription files.
# Processing 398 out of 1706 transcription files.
# Processing 399 out of 1706 transcription files.
# Processing 400 out of 1706 transcription files.
# Processing 401 out of 1706 transcription files.
# Processing 402 out of 1706 transcription files.
# Processing 403 out of 1706 transcription files.
# Processing 404 out of 1706 transcription files.
# Processing 405 out of 1706 transcription files.
# Processing 406 out of 1706 transcription files.
# ID 405 Failed
# Processing 407 out of 1706 transcription files.
# Processing 408 out of 1706 transcription files.
# Processing 409 out of 1706 transcription files.
# Processing 410 out of 1706 transcription files.
# Processing 411 out of 1706 transcription files.
# Processing 412 out of 1706 transcription files.
# Processing 413 out of 1706 transcription files.
# Processing 414 out of 1706 transcription files.
# Processing 415 out of 1706 transcription files.
# Processing 416 out of 1706 transcription files.
# Processing 417 out of 1706 transcription files.
# Processing 418 out of 1706 transcription files.
# Processing 419 out of 1706 transcription files.
# Processing 420 out of 1706 transcription files.
# Processing 421 out of 1706 transcription files.
# Processing 422 out of 1706 transcription files.
# Processing 423 out of 1706 transcription files.
# Processing 424 out of 1706 transcription files.
# Processing 425 out of 1706 transcription files.
# Processing 426 out of 1706 transcription files.
# Processing 427 out of 1706 transcription files.
# Processing 428 out of 1706 transcription files.
# Processing 429 out of 1706 transcription files.
# Processing 430 out of 1706 transcription files.
# ID 429 Failed
# Processing 431 out of 1706 transcription files.
# Processing 432 out of 1706 transcription files.
# Processing 433 out of 1706 transcription files.
# Processing 434 out of 1706 transcription files.
# Processing 435 out of 1706 transcription files.
# Processing 436 out of 1706 transcription files.
# Processing 437 out of 1706 transcription files.
# Processing 438 out of 1706 transcription files.
# Processing 439 out of 1706 transcription files.
# Processing 440 out of 1706 transcription files.
# Processing 441 out of 1706 transcription files.
# ID 440 Failed
# Processing 442 out of 1706 transcription files.
# Processing 443 out of 1706 transcription files.
# Processing 444 out of 1706 transcription files.
# Processing 445 out of 1706 transcription files.
# ID 444 Failed
# Processing 446 out of 1706 transcription files.
# Processing 447 out of 1706 transcription files.
# Processing 448 out of 1706 transcription files.
# Processing 449 out of 1706 transcription files.
# Processing 450 out of 1706 transcription files.
# Processing 451 out of 1706 transcription files.
# Processing 452 out of 1706 transcription files.
# ID 451 Failed
# Processing 453 out of 1706 transcription files.
# Processing 454 out of 1706 transcription files.
# Processing 455 out of 1706 transcription files.
# Processing 456 out of 1706 transcription files.
# Processing 457 out of 1706 transcription files.
# Processing 458 out of 1706 transcription files.
# Processing 459 out of 1706 transcription files.
# Processing 460 out of 1706 transcription files.
# Processing 461 out of 1706 transcription files.
# Processing 462 out of 1706 transcription files.
# Processing 463 out of 1706 transcription files.
# Processing 464 out of 1706 transcription files.
# Processing 465 out of 1706 transcription files.
# Processing 466 out of 1706 transcription files.
# Processing 467 out of 1706 transcription files.
# Processing 468 out of 1706 transcription files.
# Processing 469 out of 1706 transcription files.
# Processing 470 out of 1706 transcription files.
# Processing 471 out of 1706 transcription files.
# Processing 472 out of 1706 transcription files.
# Processing 473 out of 1706 transcription files.
# Processing 474 out of 1706 transcription files.
# Processing 475 out of 1706 transcription files.
# Processing 476 out of 1706 transcription files.
# Processing 477 out of 1706 transcription files.
# Processing 478 out of 1706 transcription files.
# Processing 479 out of 1706 transcription files.
# Processing 480 out of 1706 transcription files.
# Processing 481 out of 1706 transcription files.
# Processing 482 out of 1706 transcription files.
# Processing 483 out of 1706 transcription files.
# Processing 484 out of 1706 transcription files.
# Processing 485 out of 1706 transcription files.
# Processing 486 out of 1706 transcription files.
# Processing 487 out of 1706 transcription files.
# Processing 488 out of 1706 transcription files.
# Processing 489 out of 1706 transcription files.
# Processing 490 out of 1706 transcription files.
# Processing 491 out of 1706 transcription files.
# Processing 492 out of 1706 transcription files.
# Processing 493 out of 1706 transcription files.
# Processing 494 out of 1706 transcription files.
# Processing 495 out of 1706 transcription files.
# Processing 496 out of 1706 transcription files.
# Processing 497 out of 1706 transcription files.
# Processing 498 out of 1706 transcription files.
# Processing 499 out of 1706 transcription files.
# Processing 500 out of 1706 transcription files.
# Processing 501 out of 1706 transcription files.
# Processing 502 out of 1706 transcription files.
# Processing 503 out of 1706 transcription files.
# Processing 504 out of 1706 transcription files.
# Processing 505 out of 1706 transcription files.
# Processing 506 out of 1706 transcription files.
# Processing 507 out of 1706 transcription files.
# Processing 508 out of 1706 transcription files.
# Processing 509 out of 1706 transcription files.
# Processing 510 out of 1706 transcription files.
# Processing 511 out of 1706 transcription files.
# Processing 512 out of 1706 transcription files.
# Processing 513 out of 1706 transcription files.
# Processing 514 out of 1706 transcription files.
# audio length 599.700000
# region legnth 49.852750
# audio length 599.700000
# region legnth 49.852750
# audio length 599.700000
# region legnth 49.852750
# ID 513 Failed
# Processing 515 out of 1706 transcription files.
# Processing 516 out of 1706 transcription files.
# Processing 517 out of 1706 transcription files.
# Processing 518 out of 1706 transcription files.
# Processing 519 out of 1706 transcription files.
# Processing 520 out of 1706 transcription files.
# Processing 521 out of 1706 transcription files.
# Processing 522 out of 1706 transcription files.
# Processing 523 out of 1706 transcription files.
# Processing 524 out of 1706 transcription files.
# Processing 525 out of 1706 transcription files.
# Processing 526 out of 1706 transcription files.
# Processing 527 out of 1706 transcription files.
# Processing 528 out of 1706 transcription files.
# Processing 529 out of 1706 transcription files.
# Processing 530 out of 1706 transcription files.
# Processing 531 out of 1706 transcription files.
# Processing 532 out of 1706 transcription files.
# Processing 533 out of 1706 transcription files.
# Processing 534 out of 1706 transcription files.
# ID 533 Failed
# Processing 535 out of 1706 transcription files.
# Processing 536 out of 1706 transcription files.
# Processing 537 out of 1706 transcription files.
# Processing 538 out of 1706 transcription files.
# Processing 539 out of 1706 transcription files.
# Processing 540 out of 1706 transcription files.
# Processing 541 out of 1706 transcription files.
# Processing 542 out of 1706 transcription files.
# Processing 543 out of 1706 transcription files.
# Processing 544 out of 1706 transcription files.
# ID 543 Failed
# Processing 545 out of 1706 transcription files.
# Processing 546 out of 1706 transcription files.
# Processing 547 out of 1706 transcription files.
# Processing 548 out of 1706 transcription files.
# Processing 549 out of 1706 transcription files.
# Processing 550 out of 1706 transcription files.
# Processing 551 out of 1706 transcription files.
# Processing 552 out of 1706 transcription files.
# Processing 553 out of 1706 transcription files.
# Processing 554 out of 1706 transcription files.
# Processing 555 out of 1706 transcription files.
# Processing 556 out of 1706 transcription files.
# Processing 557 out of 1706 transcription files.
# Processing 558 out of 1706 transcription files.
# Processing 559 out of 1706 transcription files.
# Processing 560 out of 1706 transcription files.
# Processing 561 out of 1706 transcription files.
# Processing 562 out of 1706 transcription files.
# Processing 563 out of 1706 transcription files.
# Processing 564 out of 1706 transcription files.
# Processing 565 out of 1706 transcription files.
# Processing 566 out of 1706 transcription files.
# Processing 567 out of 1706 transcription files.
# Processing 568 out of 1706 transcription files.
# Processing 569 out of 1706 transcription files.
# Processing 570 out of 1706 transcription files.
# Processing 571 out of 1706 transcription files.
# Processing 572 out of 1706 transcription files.
# Processing 573 out of 1706 transcription files.
# Processing 574 out of 1706 transcription files.
# Processing 575 out of 1706 transcription files.
# Processing 576 out of 1706 transcription files.
# Processing 577 out of 1706 transcription files.
# Processing 578 out of 1706 transcription files.
# Processing 579 out of 1706 transcription files.
# Processing 580 out of 1706 transcription files.
# Processing 581 out of 1706 transcription files.
# Processing 582 out of 1706 transcription files.
# Processing 583 out of 1706 transcription files.
# Processing 584 out of 1706 transcription files.
# Processing 585 out of 1706 transcription files.
# Processing 586 out of 1706 transcription files.
# Processing 587 out of 1706 transcription files.
# Processing 588 out of 1706 transcription files.
# Processing 589 out of 1706 transcription files.
# Processing 590 out of 1706 transcription files.
# Processing 591 out of 1706 transcription files.
# Processing 592 out of 1706 transcription files.
# Processing 593 out of 1706 transcription files.
# Processing 594 out of 1706 transcription files.
# Processing 595 out of 1706 transcription files.
# Processing 596 out of 1706 transcription files.
# Processing 597 out of 1706 transcription files.
# Processing 598 out of 1706 transcription files.
# Processing 599 out of 1706 transcription files.
# Processing 600 out of 1706 transcription files.
# Processing 601 out of 1706 transcription files.
# Processing 602 out of 1706 transcription files.
# Processing 603 out of 1706 transcription files.
# Processing 604 out of 1706 transcription files.
# Processing 605 out of 1706 transcription files.
# Processing 606 out of 1706 transcription files.
# Processing 607 out of 1706 transcription files.
# Processing 608 out of 1706 transcription files.
# Processing 609 out of 1706 transcription files.
# Processing 610 out of 1706 transcription files.
# Processing 611 out of 1706 transcription files.
# Processing 612 out of 1706 transcription files.
# Processing 613 out of 1706 transcription files.
# Processing 614 out of 1706 transcription files.
# Processing 615 out of 1706 transcription files.
# Processing 616 out of 1706 transcription files.
# ID 615 Failed
# Processing 617 out of 1706 transcription files.
# Processing 618 out of 1706 transcription files.
# Processing 619 out of 1706 transcription files.
# Processing 620 out of 1706 transcription files.
# Processing 621 out of 1706 transcription files.
# Processing 622 out of 1706 transcription files.
# Processing 623 out of 1706 transcription files.
# Processing 624 out of 1706 transcription files.
# Processing 625 out of 1706 transcription files.
# Processing 626 out of 1706 transcription files.
# Processing 627 out of 1706 transcription files.
# Processing 628 out of 1706 transcription files.
# Processing 629 out of 1706 transcription files.
# Processing 630 out of 1706 transcription files.
# ID 629 Failed
# Processing 631 out of 1706 transcription files.
# Processing 632 out of 1706 transcription files.
# Processing 633 out of 1706 transcription files.
# Processing 634 out of 1706 transcription files.
# Processing 635 out of 1706 transcription files.
# Processing 636 out of 1706 transcription files.
# Processing 637 out of 1706 transcription files.
# Processing 638 out of 1706 transcription files.
# Processing 639 out of 1706 transcription files.
# Processing 640 out of 1706 transcription files.
# Processing 641 out of 1706 transcription files.
# Processing 642 out of 1706 transcription files.
# Processing 643 out of 1706 transcription files.
# Processing 644 out of 1706 transcription files.
# Processing 645 out of 1706 transcription files.
# Processing 646 out of 1706 transcription files.
# Processing 647 out of 1706 transcription files.
# Processing 648 out of 1706 transcription files.
# Processing 649 out of 1706 transcription files.
# Processing 650 out of 1706 transcription files.
# Processing 651 out of 1706 transcription files.
# Processing 652 out of 1706 transcription files.
# Processing 653 out of 1706 transcription files.
# Processing 654 out of 1706 transcription files.
# Processing 655 out of 1706 transcription files.
# Processing 656 out of 1706 transcription files.
# Processing 657 out of 1706 transcription files.
# Processing 658 out of 1706 transcription files.
# Processing 659 out of 1706 transcription files.
# Processing 660 out of 1706 transcription files.
# Processing 661 out of 1706 transcription files.
# Processing 662 out of 1706 transcription files.
# Processing 663 out of 1706 transcription files.
# Processing 664 out of 1706 transcription files.
# Processing 665 out of 1706 transcription files.
# Processing 666 out of 1706 transcription files.
# Processing 667 out of 1706 transcription files.
# Processing 668 out of 1706 transcription files.
# Processing 669 out of 1706 transcription files.
# Processing 670 out of 1706 transcription files.
# Processing 671 out of 1706 transcription files.
# Processing 672 out of 1706 transcription files.
# audio length 539.400000
# region legnth 34.069500
# ID 671 Failed
# Processing 673 out of 1706 transcription files.
# Processing 674 out of 1706 transcription files.
# Processing 675 out of 1706 transcription files.
# Processing 676 out of 1706 transcription files.
# Processing 677 out of 1706 transcription files.
# Processing 678 out of 1706 transcription files.
# Processing 679 out of 1706 transcription files.
# Processing 680 out of 1706 transcription files.
# audio length 599.100000
# region legnth 26.226500
# ID 679 Failed
# Processing 681 out of 1706 transcription files.
# Processing 682 out of 1706 transcription files.
# Processing 683 out of 1706 transcription files.
# Processing 684 out of 1706 transcription files.
# Processing 685 out of 1706 transcription files.
# Processing 686 out of 1706 transcription files.
# Processing 687 out of 1706 transcription files.
# Processing 688 out of 1706 transcription files.
# Processing 689 out of 1706 transcription files.
# Processing 690 out of 1706 transcription files.
# ID 689 Failed
# Processing 691 out of 1706 transcription files.
# Processing 692 out of 1706 transcription files.
# Processing 693 out of 1706 transcription files.
# Processing 694 out of 1706 transcription files.
# Processing 695 out of 1706 transcription files.
# Processing 696 out of 1706 transcription files.
# Processing 697 out of 1706 transcription files.
# Processing 698 out of 1706 transcription files.
# Processing 699 out of 1706 transcription files.
# Processing 700 out of 1706 transcription files.
# Processing 701 out of 1706 transcription files.
# Processing 702 out of 1706 transcription files.
# Processing 703 out of 1706 transcription files.
# Processing 704 out of 1706 transcription files.
# Processing 705 out of 1706 transcription files.
# Processing 706 out of 1706 transcription files.
# Processing 707 out of 1706 transcription files.
# Processing 708 out of 1706 transcription files.
# Processing 709 out of 1706 transcription files.
# Processing 710 out of 1706 transcription files.
# Processing 711 out of 1706 transcription files.
# Processing 712 out of 1706 transcription files.
# Processing 713 out of 1706 transcription files.
# Processing 714 out of 1706 transcription files.
# Processing 715 out of 1706 transcription files.
# Processing 716 out of 1706 transcription files.
# Processing 717 out of 1706 transcription files.
# Processing 718 out of 1706 transcription files.
# Processing 719 out of 1706 transcription files.
# Processing 720 out of 1706 transcription files.
# Processing 721 out of 1706 transcription files.
# Processing 722 out of 1706 transcription files.
# Processing 723 out of 1706 transcription files.
# Processing 724 out of 1706 transcription files.
# Processing 725 out of 1706 transcription files.
# Processing 726 out of 1706 transcription files.
# Processing 727 out of 1706 transcription files.
# Processing 728 out of 1706 transcription files.
# ID 727 Failed
# Processing 729 out of 1706 transcription files.
# Processing 730 out of 1706 transcription files.
# Processing 731 out of 1706 transcription files.
# Processing 732 out of 1706 transcription files.
# Processing 733 out of 1706 transcription files.
# Processing 734 out of 1706 transcription files.
# Processing 735 out of 1706 transcription files.
# Processing 736 out of 1706 transcription files.
# Processing 737 out of 1706 transcription files.
# Processing 738 out of 1706 transcription files.
# Processing 739 out of 1706 transcription files.
# Processing 740 out of 1706 transcription files.
# Processing 741 out of 1706 transcription files.
# Processing 742 out of 1706 transcription files.
# Processing 743 out of 1706 transcription files.
# Processing 744 out of 1706 transcription files.
# Processing 745 out of 1706 transcription files.
# Processing 746 out of 1706 transcription files.
# Processing 747 out of 1706 transcription files.
# Processing 748 out of 1706 transcription files.
# Processing 749 out of 1706 transcription files.
# Processing 750 out of 1706 transcription files.
# Processing 751 out of 1706 transcription files.
# Processing 752 out of 1706 transcription files.
# Processing 753 out of 1706 transcription files.
# Processing 754 out of 1706 transcription files.
# Processing 755 out of 1706 transcription files.
# Processing 756 out of 1706 transcription files.
# Processing 757 out of 1706 transcription files.
# Processing 758 out of 1706 transcription files.
# Processing 759 out of 1706 transcription files.
# ID 758 Failed
# Processing 760 out of 1706 transcription files.
# Processing 761 out of 1706 transcription files.
# Processing 762 out of 1706 transcription files.
# Processing 763 out of 1706 transcription files.
# Processing 764 out of 1706 transcription files.
# Processing 765 out of 1706 transcription files.
# Processing 766 out of 1706 transcription files.
# Processing 767 out of 1706 transcription files.
# audio length 366.400000
# region legnth 38.397750
# audio length 366.400000
# region legnth 38.397750
# ID 766 Failed
# Processing 768 out of 1706 transcription files.
# Processing 769 out of 1706 transcription files.
# Processing 770 out of 1706 transcription files.
# Processing 771 out of 1706 transcription files.
# Processing 772 out of 1706 transcription files.
# Processing 773 out of 1706 transcription files.
# Processing 774 out of 1706 transcription files.
# Processing 775 out of 1706 transcription files.
# Processing 776 out of 1706 transcription files.
# Processing 777 out of 1706 transcription files.
# Processing 778 out of 1706 transcription files.
# Processing 779 out of 1706 transcription files.
# Processing 780 out of 1706 transcription files.
# Processing 781 out of 1706 transcription files.
# Processing 782 out of 1706 transcription files.
# Processing 783 out of 1706 transcription files.
# Processing 784 out of 1706 transcription files.
# Processing 785 out of 1706 transcription files.
# Processing 786 out of 1706 transcription files.
# Processing 787 out of 1706 transcription files.
# Processing 788 out of 1706 transcription files.
# Processing 789 out of 1706 transcription files.
# Processing 790 out of 1706 transcription files.
# Processing 791 out of 1706 transcription files.
# Processing 792 out of 1706 transcription files.
# Processing 793 out of 1706 transcription files.
# Processing 794 out of 1706 transcription files.
# Processing 795 out of 1706 transcription files.
# Processing 796 out of 1706 transcription files.
# Processing 797 out of 1706 transcription files.
# Processing 798 out of 1706 transcription files.
# Processing 799 out of 1706 transcription files.
# Processing 800 out of 1706 transcription files.
# Processing 801 out of 1706 transcription files.
# Processing 802 out of 1706 transcription files.
# Processing 803 out of 1706 transcription files.
# Processing 804 out of 1706 transcription files.
# Processing 805 out of 1706 transcription files.
# Processing 806 out of 1706 transcription files.
# Processing 807 out of 1706 transcription files.
# Processing 808 out of 1706 transcription files.
# Processing 809 out of 1706 transcription files.
# Processing 810 out of 1706 transcription files.
# Processing 811 out of 1706 transcription files.
# Processing 812 out of 1706 transcription files.
# Processing 813 out of 1706 transcription files.
# Processing 814 out of 1706 transcription files.
# Processing 815 out of 1706 transcription files.
# Processing 816 out of 1706 transcription files.
# Processing 817 out of 1706 transcription files.
# Processing 818 out of 1706 transcription files.
# Processing 819 out of 1706 transcription files.
# Processing 820 out of 1706 transcription files.
# Processing 821 out of 1706 transcription files.
# ID 820 Failed
# Processing 822 out of 1706 transcription files.
# Processing 823 out of 1706 transcription files.
# Processing 824 out of 1706 transcription files.
# Processing 825 out of 1706 transcription files.
# Processing 826 out of 1706 transcription files.
# Processing 827 out of 1706 transcription files.
# Processing 828 out of 1706 transcription files.
# Processing 829 out of 1706 transcription files.
# Processing 830 out of 1706 transcription files.
# Processing 831 out of 1706 transcription files.
# Processing 832 out of 1706 transcription files.
# Processing 833 out of 1706 transcription files.
# Processing 834 out of 1706 transcription files.
# Processing 835 out of 1706 transcription files.
# Processing 836 out of 1706 transcription files.
# Processing 837 out of 1706 transcription files.
# Processing 838 out of 1706 transcription files.
# Processing 839 out of 1706 transcription files.
# Processing 840 out of 1706 transcription files.
# Processing 841 out of 1706 transcription files.
# Processing 842 out of 1706 transcription files.
# Processing 843 out of 1706 transcription files.
# Processing 844 out of 1706 transcription files.
# Processing 845 out of 1706 transcription files.
# Processing 846 out of 1706 transcription files.
# Processing 847 out of 1706 transcription files.
# Processing 848 out of 1706 transcription files.
# Processing 849 out of 1706 transcription files.
# Processing 850 out of 1706 transcription files.
# Processing 851 out of 1706 transcription files.
# Processing 852 out of 1706 transcription files.
# Processing 853 out of 1706 transcription files.
# Processing 854 out of 1706 transcription files.
# Processing 855 out of 1706 transcription files.
# Processing 856 out of 1706 transcription files.
# Processing 857 out of 1706 transcription files.
# Processing 858 out of 1706 transcription files.
# Processing 859 out of 1706 transcription files.
# Processing 860 out of 1706 transcription files.
# Processing 861 out of 1706 transcription files.
# Processing 862 out of 1706 transcription files.
# Processing 863 out of 1706 transcription files.
# Processing 864 out of 1706 transcription files.
# Processing 865 out of 1706 transcription files.
# Processing 866 out of 1706 transcription files.
# Processing 867 out of 1706 transcription files.
# Processing 868 out of 1706 transcription files.
# Processing 869 out of 1706 transcription files.
# Processing 870 out of 1706 transcription files.
# Processing 871 out of 1706 transcription files.
# Processing 872 out of 1706 transcription files.
# Processing 873 out of 1706 transcription files.
# Processing 874 out of 1706 transcription files.
# Processing 875 out of 1706 transcription files.
# Processing 876 out of 1706 transcription files.
# Processing 877 out of 1706 transcription files.
# Processing 878 out of 1706 transcription files.
# Processing 879 out of 1706 transcription files.
# audio length 449.900000
# region legnth 31.261375
# audio length 449.900000
# region legnth 31.261375
# audio length 449.900000
# region legnth 31.261375
# ID 878 Failed
# Processing 880 out of 1706 transcription files.
# Processing 881 out of 1706 transcription files.
# Processing 882 out of 1706 transcription files.
# Processing 883 out of 1706 transcription files.
# Processing 884 out of 1706 transcription files.
# ID 883 Failed
# Processing 885 out of 1706 transcription files.
# Processing 886 out of 1706 transcription files.
# Processing 887 out of 1706 transcription files.
# Processing 888 out of 1706 transcription files.
# Processing 889 out of 1706 transcription files.
# Processing 890 out of 1706 transcription files.
# Processing 891 out of 1706 transcription files.
# Processing 892 out of 1706 transcription files.
# Processing 893 out of 1706 transcription files.
# Processing 894 out of 1706 transcription files.
# Processing 895 out of 1706 transcription files.
# Processing 896 out of 1706 transcription files.
# Processing 897 out of 1706 transcription files.
# Processing 898 out of 1706 transcription files.
# Processing 899 out of 1706 transcription files.
# Processing 900 out of 1706 transcription files.
# Processing 901 out of 1706 transcription files.
# Processing 902 out of 1706 transcription files.
# Processing 903 out of 1706 transcription files.
# Processing 904 out of 1706 transcription files.
# Processing 905 out of 1706 transcription files.
# Processing 906 out of 1706 transcription files.
# Processing 907 out of 1706 transcription files.
# Processing 908 out of 1706 transcription files.
# Processing 909 out of 1706 transcription files.
# Processing 910 out of 1706 transcription files.
# Processing 911 out of 1706 transcription files.
# Processing 912 out of 1706 transcription files.
# Processing 913 out of 1706 transcription files.
# Processing 914 out of 1706 transcription files.
# Processing 915 out of 1706 transcription files.
# Processing 916 out of 1706 transcription files.
# Processing 917 out of 1706 transcription files.
# Processing 918 out of 1706 transcription files.
# Processing 919 out of 1706 transcription files.
# Processing 920 out of 1706 transcription files.
# Processing 921 out of 1706 transcription files.
# Processing 922 out of 1706 transcription files.
# Processing 923 out of 1706 transcription files.
# audio length 599.300000
# region legnth 41.367500
# ID 922 Failed
# Processing 924 out of 1706 transcription files.
# Processing 925 out of 1706 transcription files.
# Processing 926 out of 1706 transcription files.
# Processing 927 out of 1706 transcription files.
# Processing 928 out of 1706 transcription files.
# Processing 929 out of 1706 transcription files.
# Processing 930 out of 1706 transcription files.
# ID 929 Failed
# Processing 931 out of 1706 transcription files.
# Processing 932 out of 1706 transcription files.
# Processing 933 out of 1706 transcription files.
# Processing 934 out of 1706 transcription files.
# Processing 935 out of 1706 transcription files.
# Processing 936 out of 1706 transcription files.
# Processing 937 out of 1706 transcription files.
# Processing 938 out of 1706 transcription files.
# Processing 939 out of 1706 transcription files.
# Processing 940 out of 1706 transcription files.
# Processing 941 out of 1706 transcription files.
# Processing 942 out of 1706 transcription files.
# Processing 943 out of 1706 transcription files.
# Processing 944 out of 1706 transcription files.
# Processing 945 out of 1706 transcription files.
# Processing 946 out of 1706 transcription files.
# Processing 947 out of 1706 transcription files.
# ID 946 Failed
# Processing 948 out of 1706 transcription files.
# Processing 949 out of 1706 transcription files.
# Processing 950 out of 1706 transcription files.
# Processing 951 out of 1706 transcription files.
# Processing 952 out of 1706 transcription files.
# Processing 953 out of 1706 transcription files.
# Processing 954 out of 1706 transcription files.
# Processing 955 out of 1706 transcription files.
# Processing 956 out of 1706 transcription files.
# Processing 957 out of 1706 transcription files.
# Processing 958 out of 1706 transcription files.
# Processing 959 out of 1706 transcription files.
# Processing 960 out of 1706 transcription files.
# Processing 961 out of 1706 transcription files.
# Processing 962 out of 1706 transcription files.
# Processing 963 out of 1706 transcription files.
# Processing 964 out of 1706 transcription files.
# Processing 965 out of 1706 transcription files.
# Processing 966 out of 1706 transcription files.
# Processing 967 out of 1706 transcription files.
# Processing 968 out of 1706 transcription files.
# Processing 969 out of 1706 transcription files.
# Processing 970 out of 1706 transcription files.
# Processing 971 out of 1706 transcription files.
# Processing 972 out of 1706 transcription files.
# ...
# Processing 1387 out of 1706 transcription files.
# Processing 1388 out of 1706 transcription files.
# Processing 1389 out of 1706 transcription files.
# Processing 1390 out of 1706 transcription files.
# Processing 1391 out of 1706 transcription files.
# Processing 1392 out of 1706 transcription files.
# Processing 1393 out of 1706 transcription files.
# ID 1392 Failed
# Processing 1394 out of 1706 transcription files.
# Processing 1395 out of 1706 transcription files.
# ID 1394 Failed
# Processing 1396 out of 1706 transcription files.
# Processing 1397 out of 1706 transcription files.
# Processing 1398 out of 1706 transcription files.
# Processing 1399 out of 1706 transcription files.
# Processing 1400 out of 1706 transcription files.
# Processing 1401 out of 1706 transcription files.
# Processing 1402 out of 1706 transcription files.
# Processing 1403 out of 1706 transcription files.
# Processing 1404 out of 1706 transcription files.
# Processing 1405 out of 1706 transcription files.
# Processing 1406 out of 1706 transcription files.
# Processing 1407 out of 1706 transcription files.
# Processing 1408 out of 1706 transcription files.
# Processing 1409 out of 1706 transcription files.
# Processing 1410 out of 1706 transcription files.
# Processing 1411 out of 1706 transcription files.
# Processing 1412 out of 1706 transcription files.
# Processing 1413 out of 1706 transcription files.
# Processing 1414 out of 1706 transcription files.
# Processing 1415 out of 1706 transcription files.
# Processing 1416 out of 1706 transcription files.
# Processing 1417 out of 1706 transcription files.
# Processing 1418 out of 1706 transcription files.
# Processing 1419 out of 1706 transcription files.
# Processing 1420 out of 1706 transcription files.
# Processing 1421 out of 1706 transcription files.
# Processing 1422 out of 1706 transcription files.
# Processing 1423 out of 1706 transcription files.
# Processing 1424 out of 1706 transcription files.
# Processing 1425 out of 1706 transcription files.
# Processing 1426 out of 1706 transcription files.
# Processing 1427 out of 1706 transcription files.
# Processing 1428 out of 1706 transcription files.
# Processing 1429 out of 1706 transcription files.
# Processing 1430 out of 1706 transcription files.
# Processing 1431 out of 1706 transcription files.
# Processing 1432 out of 1706 transcription files.
# Processing 1433 out of 1706 transcription files.
# Processing 1434 out of 1706 transcription files.
# Processing 1435 out of 1706 transcription files.
# Processing 1436 out of 1706 transcription files.
# Processing 1437 out of 1706 transcription files.
# Processing 1438 out of 1706 transcription files.
# Processing 1439 out of 1706 transcription files.
# Processing 1440 out of 1706 transcription files.
# Processing 1441 out of 1706 transcription files.
# Processing 1442 out of 1706 transcription files.
# Processing 1443 out of 1706 transcription files.
# Processing 1444 out of 1706 transcription files.
# Processing 1445 out of 1706 transcription files.
# Processing 1446 out of 1706 transcription files.
# Processing 1447 out of 1706 transcription files.
# Processing 1448 out of 1706 transcription files.
# Processing 1449 out of 1706 transcription files.
# Processing 1450 out of 1706 transcription files.
# Processing 1451 out of 1706 transcription files.
# Processing 1452 out of 1706 transcription files.
# Processing 1453 out of 1706 transcription files.
# Processing 1454 out of 1706 transcription files.
# Processing 1455 out of 1706 transcription files.
# Processing 1456 out of 1706 transcription files.
# Processing 1457 out of 1706 transcription files.
# Processing 1458 out of 1706 transcription files.
# Processing 1459 out of 1706 transcription files.
# Processing 1460 out of 1706 transcription files.
# Processing 1461 out of 1706 transcription files.
# Processing 1462 out of 1706 transcription files.
# Processing 1463 out of 1706 transcription files.
# Processing 1464 out of 1706 transcription files.
# Processing 1465 out of 1706 transcription files.
# Processing 1466 out of 1706 transcription files.
# Processing 1467 out of 1706 transcription files.
# Processing 1468 out of 1706 transcription files.
# Processing 1469 out of 1706 transcription files.
# Processing 1470 out of 1706 transcription files.
# Processing 1471 out of 1706 transcription files.
# Processing 1472 out of 1706 transcription files.
# Processing 1473 out of 1706 transcription files.
# ID 1472 Failed
# Processing 1474 out of 1706 transcription files.
# Processing 1475 out of 1706 transcription files.
# Processing 1476 out of 1706 transcription files.
# Processing 1477 out of 1706 transcription files.
# Processing 1478 out of 1706 transcription files.
# Processing 1479 out of 1706 transcription files.
# Processing 1480 out of 1706 transcription files.
# Processing 1481 out of 1706 transcription files.
# ID 1480 Failed
# Processing 1482 out of 1706 transcription files.
# Processing 1483 out of 1706 transcription files.
# Processing 1484 out of 1706 transcription files.
# Processing 1485 out of 1706 transcription files.
# ID 1484 Failed
# Processing 1486 out of 1706 transcription files.
# Processing 1487 out of 1706 transcription files.
# Processing 1488 out of 1706 transcription files.
# Processing 1489 out of 1706 transcription files.
# Processing 1490 out of 1706 transcription files.
# Processing 1491 out of 1706 transcription files.
# Processing 1492 out of 1706 transcription files.
# Processing 1493 out of 1706 transcription files.
# Processing 1494 out of 1706 transcription files.
# Processing 1495 out of 1706 transcription files.
# Processing 1496 out of 1706 transcription files.
# Processing 1497 out of 1706 transcription files.
# Processing 1498 out of 1706 transcription files.
# Processing 1499 out of 1706 transcription files.
# Processing 1500 out of 1706 transcription files.
# Processing 1501 out of 1706 transcription files.
# Processing 1502 out of 1706 transcription files.
# Processing 1503 out of 1706 transcription files.
# Processing 1504 out of 1706 transcription files.
# Processing 1505 out of 1706 transcription files.
# Processing 1506 out of 1706 transcription files.
# Processing 1507 out of 1706 transcription files.
# Processing 1508 out of 1706 transcription files.
# audio length 298.500000
# region legnth 40.188750
# audio length 298.500000
# region legnth 40.188750
# ID 1507 Failed
# Processing 1509 out of 1706 transcription files.
# Processing 1510 out of 1706 transcription files.
# Processing 1511 out of 1706 transcription files.
# Processing 1512 out of 1706 transcription files.
# Processing 1513 out of 1706 transcription files.
# Processing 1514 out of 1706 transcription files.
# Processing 1515 out of 1706 transcription files.
# Processing 1516 out of 1706 transcription files.
# Processing 1517 out of 1706 transcription files.
# Processing 1518 out of 1706 transcription files.
# Processing 1519 out of 1706 transcription files.
# Processing 1520 out of 1706 transcription files.
# Processing 1521 out of 1706 transcription files.
# Processing 1522 out of 1706 transcription files.
# Processing 1523 out of 1706 transcription files.
# Processing 1524 out of 1706 transcription files.
# Processing 1525 out of 1706 transcription files.
# Processing 1526 out of 1706 transcription files.
# Processing 1527 out of 1706 transcription files.
# Processing 1528 out of 1706 transcription files.
# Processing 1529 out of 1706 transcription files.
# Processing 1530 out of 1706 transcription files.
# Processing 1531 out of 1706 transcription files.
# Processing 1532 out of 1706 transcription files.
# Processing 1533 out of 1706 transcription files.
# Processing 1534 out of 1706 transcription files.
# Processing 1535 out of 1706 transcription files.
# Processing 1536 out of 1706 transcription files.
# Processing 1537 out of 1706 transcription files.
# Processing 1538 out of 1706 transcription files.
# Processing 1539 out of 1706 transcription files.
# Processing 1540 out of 1706 transcription files.
# Processing 1541 out of 1706 transcription files.
# Processing 1542 out of 1706 transcription files.
# Processing 1543 out of 1706 transcription files.
# Processing 1544 out of 1706 transcription files.
# Processing 1545 out of 1706 transcription files.
# Processing 1546 out of 1706 transcription files.
# Processing 1547 out of 1706 transcription files.
# Processing 1548 out of 1706 transcription files.
# Processing 1549 out of 1706 transcription files.
# Processing 1550 out of 1706 transcription files.
# Processing 1551 out of 1706 transcription files.
# Processing 1552 out of 1706 transcription files.
# Processing 1553 out of 1706 transcription files.
# Processing 1554 out of 1706 transcription files.
# Processing 1555 out of 1706 transcription files.
# Processing 1556 out of 1706 transcription files.
# Processing 1557 out of 1706 transcription files.
# Processing 1558 out of 1706 transcription files.
# Processing 1559 out of 1706 transcription files.
# Processing 1560 out of 1706 transcription files.
# Processing 1561 out of 1706 transcription files.
# Processing 1562 out of 1706 transcription files.
# Processing 1563 out of 1706 transcription files.
# Processing 1564 out of 1706 transcription files.
# Processing 1565 out of 1706 transcription files.
# Processing 1566 out of 1706 transcription files.
# Processing 1567 out of 1706 transcription files.
# Processing 1568 out of 1706 transcription files.
# Processing 1569 out of 1706 transcription files.
# Processing 1570 out of 1706 transcription files.
# Processing 1571 out of 1706 transcription files.
# ID 1570 Failed
# Processing 1572 out of 1706 transcription files.
# Processing 1573 out of 1706 transcription files.
# ID 1572 Failed
# Processing 1574 out of 1706 transcription files.
# Processing 1575 out of 1706 transcription files.
# Processing 1576 out of 1706 transcription files.
# Processing 1577 out of 1706 transcription files.
# Processing 1578 out of 1706 transcription files.
# Processing 1579 out of 1706 transcription files.
# Processing 1580 out of 1706 transcription files.
# Processing 1581 out of 1706 transcription files.
# Processing 1582 out of 1706 transcription files.
# Processing 1583 out of 1706 transcription files.
# Processing 1584 out of 1706 transcription files.
# Processing 1585 out of 1706 transcription files.
# Processing 1586 out of 1706 transcription files.
# Processing 1587 out of 1706 transcription files.
# Processing 1588 out of 1706 transcription files.
# Processing 1589 out of 1706 transcription files.
# Processing 1590 out of 1706 transcription files.
# Processing 1591 out of 1706 transcription files.
# Processing 1592 out of 1706 transcription files.
# Processing 1593 out of 1706 transcription files.
# Processing 1594 out of 1706 transcription files.
# Processing 1595 out of 1706 transcription files.
# Processing 1596 out of 1706 transcription files.
# Processing 1597 out of 1706 transcription files.
# Processing 1598 out of 1706 transcription files.
# Processing 1599 out of 1706 transcription files.
# Processing 1600 out of 1706 transcription files.
# Processing 1601 out of 1706 transcription files.
# Processing 1602 out of 1706 transcription files.
# Processing 1603 out of 1706 transcription files.
# Processing 1604 out of 1706 transcription files.
# Processing 1605 out of 1706 transcription files.
# Processing 1606 out of 1706 transcription files.
# Processing 1607 out of 1706 transcription files.
# Processing 1608 out of 1706 transcription files.
# Processing 1609 out of 1706 transcription files.
# Processing 1610 out of 1706 transcription files.
# Processing 1611 out of 1706 transcription files.
# Processing 1612 out of 1706 transcription files.
# Processing 1613 out of 1706 transcription files.
# Processing 1614 out of 1706 transcription files.
# Processing 1615 out of 1706 transcription files.
# Processing 1616 out of 1706 transcription files.
# Processing 1617 out of 1706 transcription files.
# Processing 1618 out of 1706 transcription files.
# Processing 1619 out of 1706 transcription files.
# Processing 1620 out of 1706 transcription files.
# Processing 1621 out of 1706 transcription files.
# Processing 1622 out of 1706 transcription files.
# Processing 1623 out of 1706 transcription files.
# Processing 1624 out of 1706 transcription files.
# Processing 1625 out of 1706 transcription files.
# Processing 1626 out of 1706 transcription files.
# Processing 1627 out of 1706 transcription files.
# Processing 1628 out of 1706 transcription files.
# Processing 1629 out of 1706 transcription files.
# Processing 1630 out of 1706 transcription files.
# Processing 1631 out of 1706 transcription files.
# Processing 1632 out of 1706 transcription files.
# Processing 1633 out of 1706 transcription files.
# Processing 1634 out of 1706 transcription files.
# Processing 1635 out of 1706 transcription files.
# Processing 1636 out of 1706 transcription files.
# Processing 1637 out of 1706 transcription files.
# Processing 1638 out of 1706 transcription files.
# Processing 1639 out of 1706 transcription files.
# Processing 1640 out of 1706 transcription files.
# Processing 1641 out of 1706 transcription files.
# Processing 1642 out of 1706 transcription files.
# Processing 1643 out of 1706 transcription files.
# Processing 1644 out of 1706 transcription files.
# Processing 1645 out of 1706 transcription files.
# Processing 1646 out of 1706 transcription files.
# ID 1645 Failed
# Processing 1647 out of 1706 transcription files.
# Processing 1648 out of 1706 transcription files.
# Processing 1649 out of 1706 transcription files.
# Processing 1650 out of 1706 transcription files.
# Processing 1651 out of 1706 transcription files.
# Processing 1652 out of 1706 transcription files.
# Processing 1653 out of 1706 transcription files.
# Processing 1654 out of 1706 transcription files.
# Processing 1655 out of 1706 transcription files.
# Processing 1656 out of 1706 transcription files.
# Processing 1657 out of 1706 transcription files.
# Processing 1658 out of 1706 transcription files.
# Processing 1659 out of 1706 transcription files.
# Processing 1660 out of 1706 transcription files.
# Processing 1661 out of 1706 transcription files.
# Processing 1662 out of 1706 transcription files.
# Processing 1663 out of 1706 transcription files.
# Processing 1664 out of 1706 transcription files.
# Processing 1665 out of 1706 transcription files.
# Processing 1666 out of 1706 transcription files.
# Processing 1667 out of 1706 transcription files.
# Processing 1668 out of 1706 transcription files.
# Processing 1669 out of 1706 transcription files.
# Processing 1670 out of 1706 transcription files.
# Processing 1671 out of 1706 transcription files.
# Processing 1672 out of 1706 transcription files.
# Processing 1673 out of 1706 transcription files.
# Processing 1674 out of 1706 transcription files.
# Processing 1675 out of 1706 transcription files.
# Processing 1676 out of 1706 transcription files.
# Processing 1677 out of 1706 transcription files.
# Processing 1678 out of 1706 transcription files.
# Processing 1679 out of 1706 transcription files.
# Processing 1680 out of 1706 transcription files.
# Processing 1681 out of 1706 transcription files.
# Processing 1682 out of 1706 transcription files.
# Processing 1683 out of 1706 transcription files.
# Processing 1684 out of 1706 transcription files.
# Processing 1685 out of 1706 transcription files.
# Processing 1686 out of 1706 transcription files.
# Processing 1687 out of 1706 transcription files.
# Processing 1688 out of 1706 transcription files.
# Processing 1689 out of 1706 transcription files.
# Processing 1690 out of 1706 transcription files.
# Processing 1691 out of 1706 transcription files.
# Processing 1692 out of 1706 transcription files.
# Processing 1693 out of 1706 transcription files.
# Processing 1694 out of 1706 transcription files.
# Processing 1695 out of 1706 transcription files.
# Processing 1696 out of 1706 transcription files.
# Processing 1697 out of 1706 transcription files.
# Processing 1698 out of 1706 transcription files.
# Processing 1699 out of 1706 transcription files.
# Processing 1700 out of 1706 transcription files.
# Processing 1701 out of 1706 transcription files.
# audio length 268.900000
# region legnth 30.721500
# ID 1700 Failed
# Processing 1702 out of 1706 transcription files.
# Processing 1703 out of 1706 transcription files.
# Processing 1704 out of 1706 transcription files.
# Processing 1705 out of 1706 transcription files.
# Processing 1706 out of 1706 transcription files.

# %%
compute_all_features(val_transcription_files, VALIDATION_OUTPUT_DIR)
# Out:
# Processing 1 out of 346 transcription files.
# Processing 2 out of 346 transcription files.
# Processing 3 out of 346 transcription files.
# Processing 4 out of 346 transcription files.
# Processing 5 out of 346 transcription files.
# Processing 6 out of 346 transcription files.
# Processing 7 out of 346 transcription files.
# Processing 8 out of 346 transcription files.
# Processing 9 out of 346 transcription files.
# Processing 10 out of 346 transcription files.
# Processing 11 out of 346 transcription files.
# Processing 12 out of 346 transcription files.
# Processing 13 out of 346 transcription files.
# Processing 14 out of 346 transcription files.
# Processing 15 out of 346 transcription files.
# Processing 16 out of 346 transcription files.
# ID 15 Failed
# Processing 17 out of 346 transcription files.
# Processing 18 out of 346 transcription files.
# Processing 19 out of 346 transcription files.
# Processing 20 out of 346 transcription files.
# Processing 21 out of 346 transcription files.
# Processing 22 out of 346 transcription files.
# Processing 23 out of 346 transcription files.
# Processing 24 out of 346 transcription files.
# Processing 25 out of 346 transcription files.
# Processing 26 out of 346 transcription files.
# Processing 27 out of 346 transcription files.
# Processing 28 out of 346 transcription files.
# Processing 29 out of 346 transcription files.
# Processing 30 out of 346 transcription files.
# Processing 31 out of 346 transcription files.
# Processing 32 out of 346 transcription files.
# Processing 33 out of 346 transcription files.
# Processing 34 out of 346 transcription files.
# Processing 35 out of 346 transcription files.
# Processing 36 out of 346 transcription files.
# Processing 37 out of 346 transcription files.
# Processing 38 out of 346 transcription files.
# Processing 39 out of 346 transcription files.
# Processing 40 out of 346 transcription files.
# Processing 41 out of 346 transcription files.
# Processing 42 out of 346 transcription files.
# Processing 43 out of 346 transcription files.
# Processing 44 out of 346 transcription files.
# Processing 45 out of 346 transcription files.
# Processing 46 out of 346 transcription files.
# Processing 47 out of 346 transcription files.
# Processing 48 out of 346 transcription files.
# Processing 49 out of 346 transcription files.
# Processing 50 out of 346 transcription files.
# Processing 51 out of 346 transcription files.
# Processing 52 out of 346 transcription files.
# Processing 53 out of 346 transcription files.
# Processing 54 out of 346 transcription files.
# Processing 55 out of 346 transcription files.
# Processing 56 out of 346 transcription files.
# Processing 57 out of 346 transcription files.
# Processing 58 out of 346 transcription files.
# Processing 59 out of 346 transcription files.
# Processing 60 out of 346 transcription files.
# Processing 61 out of 346 transcription files.
# Processing 62 out of 346 transcription files.
# Processing 63 out of 346 transcription files.
# Processing 64 out of 346 transcription files.
# Processing 65 out of 346 transcription files.
# Processing 66 out of 346 transcription files.
# Processing 67 out of 346 transcription files.
# Processing 68 out of 346 transcription files.
# Processing 69 out of 346 transcription files.
# Processing 70 out of 346 transcription files.
# Processing 71 out of 346 transcription files.
# Processing 72 out of 346 transcription files.
# Processing 73 out of 346 transcription files.
# Processing 74 out of 346 transcription files.
# Processing 75 out of 346 transcription files.
# Processing 76 out of 346 transcription files.
# ID 75 Failed
# Processing 77 out of 346 transcription files.
# Processing 78 out of 346 transcription files.
# Processing 79 out of 346 transcription files.
# Processing 80 out of 346 transcription files.
# Processing 81 out of 346 transcription files.
# Processing 82 out of 346 transcription files.
# Processing 83 out of 346 transcription files.
# Processing 84 out of 346 transcription files.
# Processing 85 out of 346 transcription files.
# Processing 86 out of 346 transcription files.
# Processing 87 out of 346 transcription files.
# Processing 88 out of 346 transcription files.
# Processing 89 out of 346 transcription files.
# Processing 90 out of 346 transcription files.
# Processing 91 out of 346 transcription files.
# Processing 92 out of 346 transcription files.
# Processing 93 out of 346 transcription files.
# Processing 94 out of 346 transcription files.
# Processing 95 out of 346 transcription files.
# Processing 96 out of 346 transcription files.
# Processing 97 out of 346 transcription files.
# Processing 98 out of 346 transcription files.
# Processing 99 out of 346 transcription files.
# Processing 100 out of 346 transcription files.
# Processing 101 out of 346 transcription files.
# Processing 102 out of 346 transcription files.
# Processing 103 out of 346 transcription files.
# Processing 104 out of 346 transcription files.
# Processing 105 out of 346 transcription files.
# Processing 106 out of 346 transcription files.
# Processing 107 out of 346 transcription files.
# Processing 108 out of 346 transcription files.
# Processing 109 out of 346 transcription files.
# Processing 110 out of 346 transcription files.
# Processing 111 out of 346 transcription files.
# Processing 112 out of 346 transcription files.
# Processing 113 out of 346 transcription files.
# Processing 114 out of 346 transcription files.
# Processing 115 out of 346 transcription files.
# ID 114 Failed
# Processing 116 out of 346 transcription files.
# Processing 117 out of 346 transcription files.
# ID 116 Failed
# Processing 118 out of 346 transcription files.
# Processing 119 out of 346 transcription files.
# Processing 120 out of 346 transcription files.
# Processing 121 out of 346 transcription files.
# Processing 122 out of 346 transcription files.
# Processing 123 out of 346 transcription files.
# Processing 124 out of 346 transcription files.
# Processing 125 out of 346 transcription files.
# Processing 126 out of 346 transcription files.
# Processing 127 out of 346 transcription files.
# Processing 128 out of 346 transcription files.
# Processing 129 out of 346 transcription files.
# Processing 130 out of 346 transcription files.
# Processing 131 out of 346 transcription files.
# Processing 132 out of 346 transcription files.
# Processing 133 out of 346 transcription files.
# Processing 134 out of 346 transcription files.
# Processing 135 out of 346 transcription files.
# Processing 136 out of 346 transcription files.
# Processing 137 out of 346 transcription files.
# Processing 138 out of 346 transcription files.
# Processing 139 out of 346 transcription files.
# Processing 140 out of 346 transcription files.
# Processing 141 out of 346 transcription files.
# Processing 142 out of 346 transcription files.
# Processing 143 out of 346 transcription files.
# Processing 144 out of 346 transcription files.
# Processing 145 out of 346 transcription files.
# Processing 146 out of 346 transcription files.
# Processing 147 out of 346 transcription files.
# Processing 148 out of 346 transcription files.
# Processing 149 out of 346 transcription files.
# Processing 150 out of 346 transcription files.
# Processing 151 out of 346 transcription files.
# Processing 152 out of 346 transcription files.
# ID 151 Failed
# Processing 153 out of 346 transcription files.
# Processing 154 out of 346 transcription files.
# Processing 155 out of 346 transcription files.
# Processing 156 out of 346 transcription files.
# Processing 157 out of 346 transcription files.
# Processing 158 out of 346 transcription files.
# Processing 159 out of 346 transcription files.
# Processing 160 out of 346 transcription files.
# Processing 161 out of 346 transcription files.
# Processing 162 out of 346 transcription files.
# Processing 163 out of 346 transcription files.
# Processing 164 out of 346 transcription files.
# Processing 165 out of 346 transcription files.
# Processing 166 out of 346 transcription files.
# Processing 167 out of 346 transcription files.
# Processing 168 out of 346 transcription files.
# Processing 169 out of 346 transcription files.
# Processing 170 out of 346 transcription files.
# Processing 171 out of 346 transcription files.
# Processing 172 out of 346 transcription files.
# Processing 173 out of 346 transcription files.
# Processing 174 out of 346 transcription files.
# Processing 175 out of 346 transcription files.
# Processing 176 out of 346 transcription files.
# Processing 177 out of 346 transcription files.
# Processing 178 out of 346 transcription files.
# Processing 179 out of 346 transcription files.
# ID 178 Failed
# Processing 180 out of 346 transcription files.
# Processing 181 out of 346 transcription files.
# Processing 182 out of 346 transcription files.
# Processing 183 out of 346 transcription files.
# Processing 184 out of 346 transcription files.
# Processing 185 out of 346 transcription files.
# Processing 186 out of 346 transcription files.
# Processing 187 out of 346 transcription files.
# Processing 188 out of 346 transcription files.
# Processing 189 out of 346 transcription files.
# Processing 190 out of 346 transcription files.
# Processing 191 out of 346 transcription files.
# Processing 192 out of 346 transcription files.
# Processing 193 out of 346 transcription files.
# Processing 194 out of 346 transcription files.
# Processing 195 out of 346 transcription files.
# Processing 196 out of 346 transcription files.
# Processing 197 out of 346 transcription files.
# Processing 198 out of 346 transcription files.
# Processing 199 out of 346 transcription files.
# Processing 200 out of 346 transcription files.
# Processing 201 out of 346 transcription files.
# Processing 202 out of 346 transcription files.
# Processing 203 out of 346 transcription files.
# Processing 204 out of 346 transcription files.
# Processing 205 out of 346 transcription files.
# Processing 206 out of 346 transcription files.
# Processing 207 out of 346 transcription files.
# Processing 208 out of 346 transcription files.
# Processing 209 out of 346 transcription files.
# Processing 210 out of 346 transcription files.
# Processing 211 out of 346 transcription files.
# Processing 212 out of 346 transcription files.
# Processing 213 out of 346 transcription files.
# ID 212 Failed
# Processing 214 out of 346 transcription files.
# Processing 215 out of 346 transcription files.
# Processing 216 out of 346 transcription files.
# Processing 217 out of 346 transcription files.
# Processing 218 out of 346 transcription files.
# Processing 219 out of 346 transcription files.
# ID 218 Failed
# Processing 220 out of 346 transcription files.
# Processing 221 out of 346 transcription files.
# Processing 222 out of 346 transcription files.
# Processing 223 out of 346 transcription files.
# Processing 224 out of 346 transcription files.
# Processing 225 out of 346 transcription files.
# Processing 226 out of 346 transcription files.
# Processing 227 out of 346 transcription files.
# Processing 228 out of 346 transcription files.
# Processing 229 out of 346 transcription files.
# Processing 230 out of 346 transcription files.
# Processing 231 out of 346 transcription files.
# Processing 232 out of 346 transcription files.
# Processing 233 out of 346 transcription files.
# Processing 234 out of 346 transcription files.
# Processing 235 out of 346 transcription files.
# Processing 236 out of 346 transcription files.
# Processing 237 out of 346 transcription files.
# Processing 238 out of 346 transcription files.
# Processing 239 out of 346 transcription files.
# Processing 240 out of 346 transcription files.
# Processing 241 out of 346 transcription files.
# Processing 242 out of 346 transcription files.
# Processing 243 out of 346 transcription files.
# Processing 244 out of 346 transcription files.
# Processing 245 out of 346 transcription files.
# Processing 246 out of 346 transcription files.
# Processing 247 out of 346 transcription files.
# Processing 248 out of 346 transcription files.
# Processing 249 out of 346 transcription files.
# Processing 250 out of 346 transcription files.
# Processing 251 out of 346 transcription files.
# Processing 252 out of 346 transcription files.
# Processing 253 out of 346 transcription files.
# Processing 254 out of 346 transcription files.
# Processing 255 out of 346 transcription files.
# Processing 256 out of 346 transcription files.
# Processing 257 out of 346 transcription files.
# Processing 258 out of 346 transcription files.
# Processing 259 out of 346 transcription files.
# ID 258 Failed
# Processing 260 out of 346 transcription files.
# Processing 261 out of 346 transcription files.
# Processing 262 out of 346 transcription files.
# Processing 263 out of 346 transcription files.
# Processing 264 out of 346 transcription files.
# Processing 265 out of 346 transcription files.
# Processing 266 out of 346 transcription files.
# Processing 267 out of 346 transcription files.
# Processing 268 out of 346 transcription files.
# Processing 269 out of 346 transcription files.
# Processing 270 out of 346 transcription files.
# Processing 271 out of 346 transcription files.
# Processing 272 out of 346 transcription files.
# Processing 273 out of 346 transcription files.
# Processing 274 out of 346 transcription files.
# Processing 275 out of 346 transcription files.
# Processing 276 out of 346 transcription files.
# audio length 299.000000
# region legnth 25.174500
# audio length 299.000000
# region legnth 25.174500
# audio length 299.000000
# region legnth 25.174500
# ID 275 Failed
# Processing 277 out of 346 transcription files.
# Processing 278 out of 346 transcription files.
# Processing 279 out of 346 transcription files.
# Processing 280 out of 346 transcription files.
# ID 279 Failed
# Processing 281 out of 346 transcription files.
# Processing 282 out of 346 transcription files.
# Processing 283 out of 346 transcription files.
# Processing 284 out of 346 transcription files.
# Processing 285 out of 346 transcription files.
# ID 284 Failed
# Processing 286 out of 346 transcription files.
# Processing 287 out of 346 transcription files.
# Processing 288 out of 346 transcription files.
# Processing 289 out of 346 transcription files.
# Processing 290 out of 346 transcription files.
# Processing 291 out of 346 transcription files.
# Processing 292 out of 346 transcription files.
# Processing 293 out of 346 transcription files.
# Processing 294 out of 346 transcription files.
# Processing 295 out of 346 transcription files.
# ID 294 Failed
# Processing 296 out of 346 transcription files.
# Processing 297 out of 346 transcription files.
# Processing 298 out of 346 transcription files.
# Processing 299 out of 346 transcription files.
# Processing 300 out of 346 transcription files.
# ID 299 Failed
# Processing 301 out of 346 transcription files.
# Processing 302 out of 346 transcription files.
# Processing 303 out of 346 transcription files.
# Processing 304 out of 346 transcription files.
# ID 303 Failed
# Processing 305 out of 346 transcription files.
# Processing 306 out of 346 transcription files.
# Processing 307 out of 346 transcription files.
# Processing 308 out of 346 transcription files.
# Processing 309 out of 346 transcription files.
# Processing 310 out of 346 transcription files.
# Processing 311 out of 346 transcription files.
# Processing 312 out of 346 transcription files.
# No audio file matched id 4361
# ID 311 Failed
# Processing 313 out of 346 transcription files.
# Processing 314 out of 346 transcription files.
# Processing 315 out of 346 transcription files.
# Processing 316 out of 346 transcription files.
# Processing 317 out of 346 transcription files.
# Processing 318 out of 346 transcription files.
# Processing 319 out of 346 transcription files.
# Processing 320 out of 346 transcription files.
# Processing 321 out of 346 transcription files.
# Processing 322 out of 346 transcription files.
# Processing 323 out of 346 transcription files.
# Processing 324 out of 346 transcription files.
# Processing 325 out of 346 transcription files.
# ID 324 Failed
# Processing 326 out of 346 transcription files.
# Processing 327 out of 346 transcription files.
# No audio file matched id 4379
# ID 326 Failed
# Processing 328 out of 346 transcription files.
# Processing 329 out of 346 transcription files.
# Processing 330 out of 346 transcription files.
# Processing 331 out of 346 transcription files.
# Processing 332 out of 346 transcription files.
# Processing 333 out of 346 transcription files.
# Processing 334 out of 346 transcription files.
# Processing 335 out of 346 transcription files.
# Processing 336 out of 346 transcription files.
# Processing 337 out of 346 transcription files.
# Processing 338 out of 346 transcription files.
# Processing 339 out of 346 transcription files.
# Processing 340 out of 346 transcription files.
# Processing 341 out of 346 transcription files.
# Processing 342 out of 346 transcription files.
# ID 341 Failed
# Processing 343 out of 346 transcription files.
# Processing 344 out of 346 transcription files.
# ID 343 Failed
# Processing 345 out of 346 transcription files.
# Processing 346 out of 346 transcription files.

# %%
compute_all_features(test_transcription_files, TEST_OUTPUT_DIR)
# Out:
# Processing 1 out of 155 transcription files.
# Processing 2 out of 155 transcription files.
# ID 1 Failed
# Processing 3 out of 155 transcription files.
# ID 2 Failed
# Processing 4 out of 155 transcription files.
# Processing 5 out of 155 transcription files.
# Processing 6 out of 155 transcription files.
# ID 5 Failed
# Processing 7 out of 155 transcription files.
# Processing 8 out of 155 transcription files.
# Processing 9 out of 155 transcription files.
# Processing 10 out of 155 transcription files.
# Processing 11 out of 155 transcription files.
# Processing 12 out of 155 transcription files.
# Processing 13 out of 155 transcription files.
# Processing 14 out of 155 transcription files.
# Processing 15 out of 155 transcription files.
# Processing 16 out of 155 transcription files.
# ID 15 Failed
# Processing 17 out of 155 transcription files.
# Processing 18 out of 155 transcription files.
# Processing 19 out of 155 transcription files.
# Processing 20 out of 155 transcription files.
# ID 19 Failed
# Processing 21 out of 155 transcription files.
# ID 20 Failed
# Processing 22 out of 155 transcription files.
# Processing 23 out of 155 transcription files.
# Processing 24 out of 155 transcription files.
# Processing 25 out of 155 transcription files.
# ID 24 Failed
# Processing 26 out of 155 transcription files.
# ID 25 Failed
# Processing 27 out of 155 transcription files.
# Processing 28 out of 155 transcription files.
# Processing 29 out of 155 transcription files.
# Processing 30 out of 155 transcription files.
# Processing 31 out of 155 transcription files.
# ID 30 Failed
# Processing 32 out of 155 transcription files.
# Processing 33 out of 155 transcription files.
# Processing 34 out of 155 transcription files.
# ID 33 Failed
# Processing 35 out of 155 transcription files.
# Processing 36 out of 155 transcription files.
# Processing 37 out of 155 transcription files.
# Processing 38 out of 155 transcription files.
# ID 37 Failed
# Processing 39 out of 155 transcription files.
# Processing 40 out of 155 transcription files.
# ID 39 Failed
# Processing 41 out of 155 transcription files.
# ID 40 Failed
# Processing 42 out of 155 transcription files.
# ID 41 Failed
# Processing 43 out of 155 transcription files.
# Processing 44 out of 155 transcription files.
# Processing 45 out of 155 transcription files.
# Processing 46 out of 155 transcription files.
# ID 45 Failed
# Processing 47 out of 155 transcription files.
# Processing 48 out of 155 transcription files.
# ID 47 Failed
# Processing 49 out of 155 transcription files.
# Processing 50 out of 155 transcription files.
# Processing 51 out of 155 transcription files.
# Processing 52 out of 155 transcription files.
# Processing 53 out of 155 transcription files.
# Processing 54 out of 155 transcription files.
# Processing 55 out of 155 transcription files.
# Processing 56 out of 155 transcription files.
# ID 55 Failed
# Processing 57 out of 155 transcription files.
# Processing 58 out of 155 transcription files.
# Processing 59 out of 155 transcription files.
# Processing 60 out of 155 transcription files.
# Processing 61 out of 155 transcription files.
# ID 60 Failed
# Processing 62 out of 155 transcription files.
# Processing 63 out of 155 transcription files.
# Processing 64 out of 155 transcription files.
# Processing 65 out of 155 transcription files.
# Processing 66 out of 155 transcription files.
# Processing 67 out of 155 transcription files.
# Processing 68 out of 155 transcription files.
# Processing 69 out of 155 transcription files.
# Processing 70 out of 155 transcription files.
# Processing 71 out of 155 transcription files.
# Processing 72 out of 155 transcription files.
# Processing 73 out of 155 transcription files.
# ID 72 Failed
# Processing 74 out of 155 transcription files.
# Processing 75 out of 155 transcription files.
# Processing 76 out of 155 transcription files.
# ID 75 Failed
# Processing 77 out of 155 transcription files.
# Processing 78 out of 155 transcription files.
# Processing 79 out of 155 transcription files.
# Processing 80 out of 155 transcription files.
# ID 79 Failed
# Processing 81 out of 155 transcription files.
# Processing 82 out of 155 transcription files.
# Processing 83 out of 155 transcription files.
# Processing 84 out of 155 transcription files.
# Processing 85 out of 155 transcription files.
# Processing 86 out of 155 transcription files.
# Processing 87 out of 155 transcription files.
# ID 86 Failed
# Processing 88 out of 155 transcription files.
# Processing 89 out of 155 transcription files.
# Processing 90 out of 155 transcription files.
# Processing 91 out of 155 transcription files.
# Processing 92 out of 155 transcription files.
# Processing 93 out of 155 transcription files.
# Processing 94 out of 155 transcription files.
# audio length 298.800000
# region legnth 16.281000
# ID 93 Failed
# Processing 95 out of 155 transcription files.
# Processing 96 out of 155 transcription files.
# Processing 97 out of 155 transcription files.
# Processing 98 out of 155 transcription files.
# Processing 99 out of 155 transcription files.
# Processing 100 out of 155 transcription files.
# Processing 101 out of 155 transcription files.
# Processing 102 out of 155 transcription files.
# Processing 103 out of 155 transcription files.
# Processing 104 out of 155 transcription files.
# Processing 105 out of 155 transcription files.
# Processing 106 out of 155 transcription files.
# Processing 107 out of 155 transcription files.
# Processing 108 out of 155 transcription files.
# Processing 109 out of 155 transcription files.
# Processing 110 out of 155 transcription files.
# Processing 111 out of 155 transcription files.
# Processing 112 out of 155 transcription files.
# Processing 113 out of 155 transcription files.
# Processing 114 out of 155 transcription files.
# Processing 115 out of 155 transcription files.
# Processing 116 out of 155 transcription files.
# Processing 117 out of 155 transcription files.
# Processing 118 out of 155 transcription files.
# Processing 119 out of 155 transcription files.
# Processing 120 out of 155 transcription files.
# Processing 121 out of 155 transcription files.
# Processing 122 out of 155 transcription files.
# Processing 123 out of 155 transcription files.
# ID 122 Failed
# Processing 124 out of 155 transcription files.
# Processing 125 out of 155 transcription files.
# Processing 126 out of 155 transcription files.
# Processing 127 out of 155 transcription files.
# Processing 128 out of 155 transcription files.
# Processing 129 out of 155 transcription files.
# Processing 130 out of 155 transcription files.
# Processing 131 out of 155 transcription files.
# Processing 132 out of 155 transcription files.
# Processing 133 out of 155 transcription files.
# Processing 134 out of 155 transcription files.
# Processing 135 out of 155 transcription files.
# Processing 136 out of 155 transcription files.
# ID 135 Failed
# Processing 137 out of 155 transcription files.
# Processing 138 out of 155 transcription files.
# Processing 139 out of 155 transcription files.
# Processing 140 out of 155 transcription files.
# Processing 141 out of 155 transcription files.
# Processing 142 out of 155 transcription files.
# Processing 143 out of 155 transcription files.
# Processing 144 out of 155 transcription files.
# Processing 145 out of 155 transcription files.
# Processing 146 out of 155 transcription files.
# Processing 147 out of 155 transcription files.
# Processing 148 out of 155 transcription files.
# Processing 149 out of 155 transcription files.
# Processing 150 out of 155 transcription files.
# Processing 151 out of 155 transcription files.
# Processing 152 out of 155 transcription files.
# Processing 153 out of 155 transcription files.
# Processing 154 out of 155 transcription files.
# Processing 155 out of 155 transcription files.
